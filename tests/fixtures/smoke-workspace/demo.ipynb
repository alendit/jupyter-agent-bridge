# %% [markdown]
# # Jupyter Agentic Bridge Smoke Fixture
#
# Use this notebook to validate that the extension can read, mutate, and execute the live notebook model.

# %%
print("ready")
# Out:
# ready\n

# %%
sum(range(5))
